# %% [markdown]
# ## Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ## Importing data file in the Python environment
# Change the Windows folder location as per your system

# %%
#### Importing Data
imp_data = pd.read_csv("C:\\Ujjwal\\Analytics\\Git\\Scenario_4\\Sample_Data.csv")
imp_data.head(2)
# Out:
#    Article_Number  Sentence_Number Article_Publish_Date           Keyword  \
# 0               0                1            7/10/2020  filed bankruptcy
# 1               0                2            7/10/2020  filed bankruptcy
#
#                                         Article_Body  \
# 0   cirque du soleil and its secured creditors ar...
# 1   cirque du soleil and its secured creditors ar...
#
#                                     Article_Keywords
# 0  cirque du soleil, a agreement, horse bid, ente...
# 1                 stake, cirque, consortium proposal

# %% [markdown]
# ## Converting Article_keywords into a list

# %%
#### Converting keywords into a list structure
imp_data["Article_Keywords_Converted"] = imp_data["Article_Keywords"].str.split(",")
imp_data.loc[0,"Article_Keywords_Converted"]
# Out:
# ['cirque du soleil',
#  ' a agreement',
#  ' horse bid',
#  ' entertainment group',
#  ' a deal',
#  ' capital',
#  ' court heard',
#  ' friday']

# %% [markdown]
# ## Solution - Pandas Version before 0.25.0

# %% [markdown]
# #### Step 1 - Convert the column containing list object to series

# %%
#### Converting each list value to series
temp_df = imp_data["Article_Keywords_Converted"].apply(pd.Series)
temp_df.head(2)
# Out:
#                  0             1                     2                     3   \
# 0  cirque du soleil   a agreement             horse bid   entertainment group
# 1             stake        cirque   consortium proposal                   NaN
#
#         4         5             6        7    8    9   ...   60   61   62  \
# 0   a deal   capital   court heard   friday  NaN  NaN  ...  NaN  NaN  NaN
# 1      NaN       NaN           NaN      NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#     63   64   65   66   67   68   69
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [2 rows x 70 columns]

# %% [markdown]
# #### Step 2 - Merge temporary dataframe with original one

# %%
#### Merging with temporary dataframe
imp_data = pd.merge(imp_data, temp_df, right_index=True, left_index=True, how = "left")
imp_data.head(2)
# Out:
#    Article_Number  Sentence_Number Article_Publish_Date           Keyword  \
# 0               0                1            7/10/2020  filed bankruptcy
# 1               0                2            7/10/2020  filed bankruptcy
#
#                                         Article_Body  \
# 0   cirque du soleil and its secured creditors ar...
# 1   cirque du soleil and its secured creditors ar...
#
#                                     Article_Keywords  \
# 0  cirque du soleil, a agreement, horse bid, ente...
# 1                 stake, cirque, consortium proposal
#
#                           Article_Keywords_Converted                 0  \
# 0  [cirque du soleil,  a agreement,  horse bid,  ...  cirque du soleil
# 1             [stake,  cirque,  consortium proposal]             stake
#
#               1                     2  ...   60   61   62   63   64   65   66  \
# 0   a agreement             horse bid  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1        cirque   consortium proposal  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     67   68   69
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
#
# [2 rows x 77 columns]

# %% [markdown]
# #### Step 3 - Melt the columns of Temporary dataframe (which are now part of the original dataframe)

# %%
#### Reshaping data
imp_data = pd.melt(imp_data, 
                   id_vars=['Article_Number','Sentence_Number',
                            'Article_Publish_Date','Keyword',
                            'Article_Body','Article_Keywords',
                            'Article_Keywords_Converted'],
                  value_name="Keywords")
imp_data.head(2)
# Out:
#    Article_Number  Sentence_Number Article_Publish_Date           Keyword  \
# 0               0                1            7/10/2020  filed bankruptcy
# 1               0                2            7/10/2020  filed bankruptcy
#
#                                         Article_Body  \
# 0   cirque du soleil and its secured creditors ar...
# 1   cirque du soleil and its secured creditors ar...
#
#                                     Article_Keywords  \
# 0  cirque du soleil, a agreement, horse bid, ente...
# 1                 stake, cirque, consortium proposal
#
#                           Article_Keywords_Converted variable  \
# 0  [cirque du soleil,  a agreement,  horse bid,  ...        0
# 1             [stake,  cirque,  consortium proposal]        0
#
#            Keywords
# 0  cirque du soleil
# 1             stake

# %% [markdown]
# #### Step 4 - Drop records with null values in keyword field and undesired columns

# %%
#### Dropping null values
imp_data.dropna(inplace = True)
imp_data.drop(["Article_Keywords", "Article_Keywords_Converted", "variable"], axis = 1, inplace=True)
imp_data.head(2)
# Out:
#    Article_Number  Sentence_Number Article_Publish_Date           Keyword  \
# 0               0                1            7/10/2020  filed bankruptcy
# 1               0                2            7/10/2020  filed bankruptcy
#
#                                         Article_Body          Keywords
# 0   cirque du soleil and its secured creditors ar...  cirque du soleil
# 1   cirque du soleil and its secured creditors ar...             stake

# %% [markdown]
# ## Solution - Pandas Version 0.25.0 and Above

# %%
#### One step solution - Explode
imp_data = pd.read_csv("C:\\Ujjwal\\Analytics\\Git\\Scenario_4\\Sample_Data.csv")
imp_data["Article_Keywords_Converted"] = imp_data["Article_Keywords"].str.split(",")
imp_data = imp_data.explode("Article_Keywords_Converted")
imp_data.head()
# Out:
#    Article_Number  Sentence_Number Article_Publish_Date           Keyword  \
# 0               0                1            7/10/2020  filed bankruptcy
# 0               0                1            7/10/2020  filed bankruptcy
# 0               0                1            7/10/2020  filed bankruptcy
# 0               0                1            7/10/2020  filed bankruptcy
# 0               0                1            7/10/2020  filed bankruptcy
#
#                                         Article_Body  \
# 0   cirque du soleil and its secured creditors ar...
# 0   cirque du soleil and its secured creditors ar...
# 0   cirque du soleil and its secured creditors ar...
# 0   cirque du soleil and its secured creditors ar...
# 0   cirque du soleil and its secured creditors ar...
#
#                                     Article_Keywords  \
# 0  cirque du soleil, a agreement, horse bid, ente...
# 0  cirque du soleil, a agreement, horse bid, ente...
# 0  cirque du soleil, a agreement, horse bid, ente...
# 0  cirque du soleil, a agreement, horse bid, ente...
# 0  cirque du soleil, a agreement, horse bid, ente...
#
#   Article_Keywords_Converted
# 0           cirque du soleil
# 0                a agreement
# 0                  horse bid
# 0        entertainment group
# 0                     a deal
